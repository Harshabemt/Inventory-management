# %%
record = {}
selection = "No"
Flag = 0
count = 1
while(True):
    print("1 : list of the Phones")
    print("2 : Quit")
    
    select = int(input("select 1 or 2: "))
    if (select == 1):
        record = { 1001: {"name":"One Plus Nord CE ", "Price": 24999 , "Quantity": 5 , "color":" black ", "RAM":" 8GB", "Storage":" 128GB "},
              1002: {"name":" Redmi 9 prime ", "Price": 10499 , "Quantity": 10, "color":" Mint Green ", "RAM":" 4GB ", "Storage":" 64GB "},
              1003: {"name":" Samsung Galaxy M12 ", "Price": 13499 , "Quantity": 8 , "color":" White ", "RAM":" 6GB ", "Storage":" 128GB "},
              1004: {"name":" Redmi Note 10 Pro Max ", "Price": 19999 , "Quantity": 6 , "color":" Vintage Bronze ", "RAM":" 6GB ", "Storage":" 128GB "},
              1005: {"name":" One Plus 9R 5G ", "Price": 39999 , "Quantity": 5 , "color":"Carbon Black ", "RAM":" 8GB ", "Storage":" 128GB "},
              1006: {"name":" Realme C11 ", "Price": 7299 , "Quantity": 5 , "color":" Cool Grey ", "RAM":" 2GB ", "Storage":" 32GB "},
              1007: {"name":" Redmi Note 10 Pro Max ", "Price": 19999 , "Quantity": 6 , "color":" Dark Night ", "RAM":" 6GB ", "Storage":" 128GB "},
              1008: {"name":" Redmi Note 10 ", "Price": 13999 , "Quantity": 6 , "color":" Shadow Black ", "RAM":" 4GB ", "Storage":" 64GB "},
              1009: {"name":" Mi 10i 5G ", "Price": 21999 , "Quantity": 3 , "color":" Midnight Black ", "RAM":" 6GB ", "Storage":" 128GB "},
              10010: {"name":" Samsung Galaxy F22 ", "Price": 14999 , "Quantity": 3 , "color":" Black ", "RAM":" 6GB ", "Storage":" 128GB "},
              10011: {"name":" One Plus Nord 2 ", "Price": 29999 , "Quantity": 5 , "color":" Blue Haze ", "RAM":" 8GB ", "Storage":" 128GB "},
              10012: {"name":" iPhone 12 Pro ", "Price": 106900 , "Quantity": 3 , "color":" pacific Black ", "RAM":" 8GB ", "Storage":" 128GB "},
              10013: {"name":" Realme 8 ", "Price": 16999 , "Quantity": 3 , "color":" Sliver ", "RAM":" 8GB ", "Storage":" 128GB "},
              10014: {"name":" Oppo A31 ", "Price": 12490 , "Quantity": 6 , "color":" Fantasy White ", "RAM":" 6GB ", "Storage":" 128GB "},
              10015: {"name":" Samsung M02s ", "Price": 9999 , "Quantity": 6 , "color":" Blue ", "RAM":" 4GB ", "Storage":" 64GB "},
              10016: {"name":" Realme Narzo 30Pro", "Price": 9479 , "Quantity": 10 , "color":" Sword Black ", "RAM":" 8GB ", "Storage":" 128GB "},
              10017: {"name":" Oppo F11 Pro", "Price": 16999 , "Quantity":" 15 ", "color":" Thunder Black ", "RAM":" 6GB ", "Storage":" 128GB "},
              10018: {"name":" Redmi 9i", "Price": 8999 , "Quantity": 5 , "color":" Nature Green ", "RAM":" 4GB ", "Storage":" 128GB "},
              10019: {"name":" Realme 7 ", "Price": 14999 , "Quantity": 6 , "color":" White ", "RAM":" 6GB ", "Storage":" 64GB "},
              10020: {"name":" Poco F1 ", "Price": 14849 , "Quantity": 5 , "color":" Armored Edition ", "RAM":" 8GB ", "Storage":" 256GB "},
              10021: {"name":" Realme Narzo 20Pro ", "Price": 12499 , "Quantity": 9 , "color":" Black ninja ", "RAM":" 6GB ", "Storage":" 64GB "},
              10022: {"name":" Redmi 9 Powder ", "Price": 11499 , "Quantity": 5 , "color":" Electric Green ", "RAM":" 4GB ", "Storage":" 64GB "},
              10023: {"name":" Samsung Galaxy Z Flip3 5G", "Price": 88999 , "Quantity": 5 , "color":" Cream ", "RAM":" 8GB ", "Storage":" 256GB "},
              10024: {"name":" Redmi 9A ", "Price": 6999 , "Quantity": 7 , "color":" Midnight Black ", "RAM":" 2GB ", "Storage":" 32GB "},
              10025: {"name":" Poco X3 ", "Price": 13999 , "Quantity": 4 , "color":" Cobalt Blue ", "RAM":" 6GB ", "Storage":" 64GB "},
              10026: {"name":" Tecno Camon 17 ", "Price": 13999 , "Quantity": 1 , "color":" Frost Sliver ", "RAM":" 6GB ", "Storage":" 128GB "},
              10027: {"name":" Samsung Galaxy Note 20 ", "Price": 55000 , "Quantity": 8 , "color":" Blue ", "RAM":" 8GB ", "Storage":" 256GB "},
              10028: {"name":" Vivo Y20G ", "Price": 12990 , "Quantity": 3 , "color":" Black ", "RAM":" 4GB ", "Storage":" 64GB "},
              10029: {"name":" Samsung M31 ", "Price": 16999 , "Quantity": 2 , "color":" Ocean Blue ", "RAM":" 8GB ", "Storage":" 128GB "},
              10030: {"name":" Google Pixel 4a ", "Price": 31999 , "Quantity": 3 , "color":" Just Black ", "RAM":" 8GB ", "Storage":" 128GB "}
             }
    
        import json
        with open("record.json", "w", encoding = "utf-8") as j:
                    json.dump(record, j, ensure_ascii=False, indent=(4))

        
        while True:
            print("1001:" , record[1001]["name"])
            print("1002:" , record[1002]["name"])
            print("1003:" , record[1003]["name"])
            print("1004:" , record[1004]["name"])
            print("1005:" , record[1005]["name"])
            print("1006:" , record[1006]["name"])
            print("1007:" , record[1007]["name"])
            print("1008:" , record[1008]["name"])
            print("1009:" , record[1009]["name"])
            print("1008:" , record[1008]["name"])
            print("1009:" , record[1009]["name"])
            print("10010:" , record[10010]["name"])
            print("10011:" , record[10011]["name"])
            print("10012:" , record[10012]["name"])
            print("10013:" , record[10013]["name"])
            print("10014:" , record[10014]["name"])
            print("10015:" , record[10015]["name"])
            print("10016:" , record[10016]["name"])
            print("10017:" , record[10017]["name"])
            print("10018:" , record[10018]["name"])
            print("10019:" , record[10019]["name"])
            print("10020:" , record[10020]["name"])
            print("10021:" , record[10021]["name"])
            print("10022:" , record[10022]["name"])
            print("10023:" , record[10023]["name"])
            print("10024:" , record[10024]["name"])
            print("10025:" , record[10025]["name"])
            print("10026:" , record[10026]["name"])
            print("10027:" , record[10027]["name"])
            print("10028:" , record[10028]["name"])
            print("10029:" , record[10029]["name"])
            print("10030:" , record[10030]["name"])              
    
            reg = int(input("Select the number for a required Phone: "))
            if (reg > 10030) or (reg < 1001):
                print('Enter a valid input')
                continue;
            print("name: ", record[reg]["name"])
            print("Price: ", record[reg]["Price"])
            print("Quantity: ", record[reg]["Quantity"])
            print("Color: ", record[reg]["color"])
            print("RAM: ", record[reg]["RAM"])
            print("Storage: ", record[reg]["Storage"])
            selection = input("Product Required ? Yes or No: ")
            if (selection == "Yes") or (selection == "yes"):

                Quantity = int(input("Enter a  Quantity: "))
                if (Quantity > record[reg]["Quantity"]):
                    print("Enter a lesser Quantity")
                    continue;
                print("name: ", record[reg]["name"])
                print("Price: ", record[reg]["Price"])
                print("Quantity: ", Quantity)
                print("total: ", record[reg]["Price"] * Quantity) 
                print("Your order has successfully placed, Thank You for ordering")
                data =   {"name: ": record[reg]["name"], "Price: ": record[reg]["Price"], "Quantity: ": Quantity, "total: ": record[reg]["Price"] * Quantity }
                
               #sales json file 
                with open("sales.json", "a", encoding = "utf-8") as j:
                    json.dump(data, j, ensure_ascii=False, indent=(4))

            
                
                Flag = 1
                break;
                
                
                
            
            elif (selection == "No") or (selection == "no"):
                N = input("Need to Continue? Yes or No : ")
                if (N == "Yes") or (N == "yes"):
                    continue;
                elif (N == "No") or (N == "no"):
                    Flag = 1
                    break;
                else :
                    print("Enter a Valid input")
              
        if Flag == 1:break;
    elif (select == 2):
            print("Thank you visit again")            
            break;
    
    else:
        print("Enter a valid Input")
